# %%
import numpy as np
import cv2
import os
import mediapipe as mp
from pathlib import Path
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler
import matplotlib.pyplot as plt
from scipy import stats
from scipy.spatial.distance import euclidean
import joblib
import warnings
warnings.filterwarnings('ignore')

# Initialize MediaPipe Holistic
mp_holistic = mp.solutions.holistic

# %%
video_dir = Path("Data/INCLUDE/Adjectives/Videos")
landmark_dir = Path("Data/INCLUDE/Adjectives/Landmarks")

#Create same class named folder in Landmark directory 
class_names = []
# Use .iterdir() to loop through the contents of the directory
for item in video_dir.iterdir():
    # Check if the item is a directory before adding its name
    if item.is_dir():
        class_names.append(item.name)
        
# Loop through your list of names and create a new folder for each
for name in class_names:
    # Construct the full path for the new folder
    new_folder_path = os.path.join(landmark_dir, name)
    
    # Create the directory. exist_ok=True prevents an error if it already exists.
    os.makedirs(new_folder_path, exist_ok=True)
print("✅ Folders created successfully!")
# Out:
# ✅ Folders created successfully!

# %%
# Globals to store expected face landmark count
EXPECTED_FACE_LANDMARKS = None

class AdvancedFeatureExtractor:
    def __init__(self):
        self.hand_landmarks = 21
        self.face_landmarks = 468
        
    def extract_hand_features(self, hand_landmarks):
        """Extract advanced hand features including velocity and acceleration"""
        if hand_landmarks.shape[0] == 0:
            return np.zeros(126)  # 42*3 features (basic + velocity + acceleration)
            
        features = []
        
        # Basic statistics
        features.extend([
            np.mean(hand_landmarks, axis=0),
            np.std(hand_landmarks, axis=0),
            np.min(hand_landmarks, axis=0),
            np.max(hand_landmarks, axis=0)
        ])
        
        # Velocity features (frame-to-frame differences)
        if hand_landmarks.shape[0] > 1:
            velocities = np.diff(hand_landmarks, axis=0)
            features.extend([
                np.mean(velocities, axis=0),
                np.std(velocities, axis=0),
            ])
        else:
            features.extend([np.zeros(42), np.zeros(42)])
            
        return np.concatenate(features)
    
    def extract_inter_hand_features(self, right_hand, left_hand):
        """Extract features between hands"""
        if right_hand.shape[0] == 0 or left_hand.shape[0] == 0:
            return np.zeros(6)
            
        # Reshape to (frames, 21, 2) for proper centroid calculation
        right_reshaped = right_hand.reshape(-1, 21, 2)
        left_reshaped = left_hand.reshape(-1, 21, 2)
        
        # Distance between hand centroids over time
        right_centroid = np.mean(right_reshaped, axis=1)
        left_centroid = np.mean(left_reshaped, axis=1)
        
        distances = [euclidean(r, l) for r, l in zip(right_centroid, left_centroid)]
        
        features = [
            np.mean(distances),
            np.std(distances),
            np.min(distances),
            np.max(distances)
        ]
        
        # Relative hand positions
        relative_positions = right_centroid - left_centroid
        features.extend([
            np.mean(relative_positions, axis=0),
            np.std(relative_positions, axis=0)
        ])
        
        return np.concatenate(features)

def extract_frame_landmarks(results):
    global EXPECTED_FACE_LANDMARKS
    lm = []
    
    # Right hand (21 points × x,y)
    if results.right_hand_landmarks:
        for p in results.right_hand_landmarks.landmark:
            lm.extend([p.x, p.y])
    else:
        lm.extend([0] * 42)
        
    # Left hand
    if results.left_hand_landmarks:
        for p in results.left_hand_landmarks.landmark:
            lm.extend([p.x, p.y])
    else:
        lm.extend([0] * 42)
        
    # Face landmarks
    face_lms = results.face_landmarks.landmark if results.face_landmarks else []
    count = len(face_lms)
    if EXPECTED_FACE_LANDMARKS is None:
        EXPECTED_FACE_LANDMARKS = count or 468
        
    for i in range(min(count, EXPECTED_FACE_LANDMARKS)):
        p = face_lms[i]
        lm.extend([p.x, p.y])
        
    missing = EXPECTED_FACE_LANDMARKS - min(count, EXPECTED_FACE_LANDMARKS)
    if missing > 0:
        lm.extend([0.0, 0.0] * missing)
    
    # Final consistency check
    total_features = 42 * 2 + EXPECTED_FACE_LANDMARKS * 2
    if len(lm) != total_features:
        raise ValueError(f"Inconsistent landmark length {len(lm)} vs expected {total_features}")
    return np.array(lm, dtype=np.float32)

def extract_advanced_features_from_sequence(sequence):
    """Extract advanced features from a landmark sequence"""
    feature_extractor = AdvancedFeatureExtractor()
    
    # Split sequence into components
    right_hand = sequence[:, :42]
    left_hand = sequence[:, 42:84]
    face = sequence[:, 84:]
    
    # Basic statistical features
    basic_features = np.concatenate([
        sequence.mean(axis=0),
        sequence.std(axis=0),
        sequence.min(axis=0),
        sequence.max(axis=0)
    ])
    
    # Advanced hand features
    right_hand_features = feature_extractor.extract_hand_features(right_hand)
    left_hand_features = feature_extractor.extract_hand_features(left_hand)
    
    # Inter-hand features
    inter_hand_features = feature_extractor.extract_inter_hand_features(right_hand, left_hand)
    
    # Temporal features
    temporal_features = []
    if sequence.shape[0] > 1:
        # Total variation (movement energy)
        total_variation = np.sum(np.abs(np.diff(sequence, axis=0)))
        temporal_features.append(total_variation)
        
        # Sequence length (normalized)
        temporal_features.append(sequence.shape[0] / 200.0)
    else:
        temporal_features.extend([0, 0])
    
    # Statistical shape features
    statistical_features = []
    try:
        statistical_features.extend([
            stats.skew(sequence, axis=0).mean(),  # Average skewness
            stats.kurtosis(sequence, axis=0).mean(),  # Average kurtosis
        ])
    except:
        statistical_features.extend([0, 0])
    
    # Combine all features
    all_features = np.concatenate([
        basic_features,
        right_hand_features,
        left_hand_features,
        inter_hand_features,
        temporal_features,
        statistical_features
    ])
    
    return all_features

# %%
def process_video(video_dir, landmark_dir, holistic_model):
    for file in os.listdir(video_dir):
        if not file.lower().endswith((".avi", ".mp4", ".mov")):
            continue
            
        video_path = os.path.join(video_dir, file)
        cap = cv2.VideoCapture(video_path)
        frames_lm = []
    
        print(f"Processing {file}...")
        frame_count = 0
    
        while True:
            ret, frame = cap.read()
            if not ret:
                break
                
            rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            results = holistic_model.process(rgb_frame)
            
            frame_landmarks = extract_frame_landmarks(results)
            frames_lm.append(frame_landmarks)
            frame_count += 1
    
        cap.release()
        
        if frames_lm:
            sequence = np.stack(frames_lm, axis=0)
            out_file = os.path.join(landmark_dir, file.rsplit(".", 1)[0] + ".npy")
            np.save(out_file, sequence)
            print(f"Saved landmarks to {out_file} with shape {sequence.shape}")

# %%
def load_data_advanced(data_root):
    """Load data with advanced feature extraction"""
    X, y = [], []
    feature_sizes = {}
    
    for category_folder in Path(data_root).iterdir():
        landmarks_root = category_folder / "Landmarks"
        if not landmarks_root.exists():
            continue
            
        for sign_folder in landmarks_root.iterdir():
            if not sign_folder.is_dir():
                continue
                
            for npy_path in sign_folder.glob("*.npy"):
                try:
                    seq = np.load(npy_path)
                    if seq.shape[0] == 0:
                        continue
                    
                    # Track feature dimensions
                    feature_dim = seq.shape[1]
                    if feature_dim not in feature_sizes:
                        feature_sizes[feature_dim] = 0
                    feature_sizes[feature_dim] += 1
                    
                    # Extract advanced features
                    advanced_features = extract_advanced_features_from_sequence(seq)
                    
                    X.append(advanced_features)
                    y.append(sign_folder.name)
                    
                except Exception as e:
                    print(f"Error processing {npy_path}: {e}")
                    continue
    
    print(f"Feature dimension distribution: {feature_sizes}")
    print(f"Loaded {len(X)} samples with {len(X[0]) if X else 0} features each")
    
    return np.vstack(X) if X else np.array([]), np.array(y)

def augment_data(X, y, augmentation_factor=1):
    """Augment data by adding noise"""
    X_aug, y_aug = [], []
    
    for i in range(len(X)):
        X_aug.append(X[i])
        y_aug.append(y[i])
        
        # Add noisy versions
        for _ in range(augmentation_factor):
            noise = np.random.normal(0, 0.01, X[i].shape)
            X_aug.append(X[i] + noise)
            y_aug.append(y[i])
            
    return np.vstack(X_aug), np.array(y_aug)

# %%
# =====================================================================================
#                         AUTOMATION CELL TO PROCESS ALL CLASSES
# =====================================================================================

BASE_VIDEO_PATH = video_dir
BASE_LANDMARK_PATH = landmark_dir

try:
    class_folders = [d for d in BASE_VIDEO_PATH.iterdir() if d.is_dir()]
    class_names = [d.name for d in class_folders]
    print(f"✅ Found {len(class_names)} classes: {class_names}\n")
except FileNotFoundError:
    print(f"❌ ERROR: The directory '{BASE_VIDEO_PATH}' was not found.")
    class_folders = []

class_averages = {}

# Process videos to landmarks
with mp_holistic.Holistic(
    static_image_mode=False,
    model_complexity=1,
    smooth_landmarks=True,
    refine_face_landmarks=True,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5
) as holistic:
    
    for class_dir in class_folders:
        class_name = class_dir.name
        print(f"================== Processing Class: {class_name} ==================")
        
        video_dir_for_class = class_dir
        landmark_dir_for_class = BASE_LANDMARK_PATH / class_name
        
        os.makedirs(landmark_dir_for_class, exist_ok=True)
        process_video(video_dir_for_class, landmark_dir_for_class, holistic)
        
        try:
            file_list = [f for f in os.listdir(landmark_dir_for_class) if f.endswith(".npy")]
            if file_list:
                frame_counts = [np.load(os.path.join(landmark_dir_for_class, f)).shape[0] for f in file_list]
                average_frame_count = np.mean(frame_counts)
                class_averages[class_name] = average_frame_count
                print(f"✅ Finished processing class '{class_name}' - Avg frames: {average_frame_count:.1f}\n")
        except Exception as e:
            print(f"❌ Error calculating average for '{class_name}': {e}\n")

print("========================================================")
print("                    📊 FINAL SUMMARY                    ")
print("========================================================")
for class_name, avg_frames in sorted(class_averages.items()):
    print(f"  ▶️  Class '{class_name}': {avg_frames:.2f} average frames")
# Out:
# ✅ Found 20 classes: ['big large', 'cold', 'cool', 'dry', 'extra', 'famous', 'fast', 'healthy', 'hot', 'light', 'long', 'narrow', 'new', 'short', 'sick', 'slow', 'small little', 'tall', 'warm', 'wide']
#
# ================== Processing Class: big large ==================
# Processing MVI_5123.MOV...
# W0000 00:00:1758269243.383574  154792 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1758269243.404376  154792 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1758269243.405537  154798 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1758269243.405716  154800 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1758269243.406602  154792 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1758269243.414435  154798 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1758269243.415056  154800 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1758269243.417409  154792 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_5123.npy with shape (54, 1040)
# Processing MVI_5124.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_5124.npy with shape (61, 1040)
# Processing MVI_5125.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_5125.npy with shape (71, 1040)
# Processing MVI_5203.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_5203.npy with shape (65, 1040)
# Processing MVI_5204.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_5204.npy with shape (70, 1040)
# Processing MVI_5205.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_5205.npy with shape (66, 1040)
# Processing MVI_5283.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_5283.npy with shape (57, 1040)
# Processing MVI_5284.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_5284.npy with shape (55, 1040)
# Processing MVI_5285.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_5285.npy with shape (51, 1040)
# Processing MVI_9233.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_9233.npy with shape (48, 1040)
# Processing MVI_9234.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_9234.npy with shape (47, 1040)
# Processing MVI_9235.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_9235.npy with shape (46, 1040)
# Processing MVI_9316.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_9316.npy with shape (44, 1040)
# Processing MVI_9317.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_9317.npy with shape (48, 1040)
# Processing MVI_9318.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_9318.npy with shape (49, 1040)
# Processing MVI_9394.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_9394.npy with shape (59, 1040)
# Processing MVI_9395.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_9395.npy with shape (57, 1040)
# Processing MVI_9396.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_9396.npy with shape (56, 1040)
# Processing MVI_9475.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_9475.npy with shape (54, 1040)
# Processing MVI_9476.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_9476.npy with shape (54, 1040)
# Processing MVI_9477.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/big large/MVI_9477.npy with shape (56, 1040)
# ✅ Finished processing class 'big large' - Avg frames: 55.6
#
# ================== Processing Class: cold ==================
# Processing MVI_5139.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_5139.npy with shape (56, 1040)
# Processing MVI_5140.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_5140.npy with shape (71, 1040)
# Processing MVI_5219.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_5219.npy with shape (56, 1040)
# Processing MVI_5220.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_5220.npy with shape (52, 1040)
# Processing MVI_5221.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_5221.npy with shape (55, 1040)
# Processing MVI_5298.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_5298.npy with shape (52, 1040)
# Processing MVI_5299.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_5299.npy with shape (57, 1040)
# Processing MVI_5300.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_5300.npy with shape (54, 1040)
# Processing MVI_9250.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_9250.npy with shape (48, 1040)
# Processing MVI_9251.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_9251.npy with shape (48, 1040)
# Processing MVI_9252.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_9252.npy with shape (49, 1040)
# Processing MVI_9331.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_9331.npy with shape (47, 1040)
# Processing MVI_9332.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_9332.npy with shape (49, 1040)
# Processing MVI_9333.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_9333.npy with shape (51, 1040)
# Processing MVI_9411.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_9411.npy with shape (54, 1040)
# Processing MVI_9412.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_9412.npy with shape (53, 1040)
# Processing MVI_9413.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_9413.npy with shape (56, 1040)
# Processing MVI_9490.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_9490.npy with shape (68, 1040)
# Processing MVI_9491.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_9491.npy with shape (65, 1040)
# Processing MVI_9492.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cold/MVI_9492.npy with shape (73, 1040)
# ✅ Finished processing class 'cold' - Avg frames: 55.7
#
# ================== Processing Class: cool ==================
# Processing MVI_5145.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_5145.npy with shape (75, 1040)
# Processing MVI_5146.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_5146.npy with shape (67, 1040)
# Processing MVI_5147.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_5147.npy with shape (68, 1040)
# Processing MVI_5225.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_5225.npy with shape (61, 1040)
# Processing MVI_5226.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_5226.npy with shape (51, 1040)
# Processing MVI_5227.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_5227.npy with shape (57, 1040)
# Processing MVI_5304.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_5304.npy with shape (50, 1040)
# Processing MVI_5305.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_5305.npy with shape (48, 1040)
# Processing MVI_5306.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_5306.npy with shape (43, 1040)
# Processing MVI_9256.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_9256.npy with shape (50, 1040)
# Processing MVI_9257.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_9257.npy with shape (46, 1040)
# Processing MVI_9258.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_9258.npy with shape (50, 1040)
# Processing MVI_9337.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_9337.npy with shape (50, 1040)
# Processing MVI_9338.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_9338.npy with shape (59, 1040)
# Processing MVI_9339.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_9339.npy with shape (53, 1040)
# Processing MVI_9418.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_9418.npy with shape (55, 1040)
# Processing MVI_9419.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_9419.npy with shape (50, 1040)
# Processing MVI_9420.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_9420.npy with shape (45, 1040)
# Processing MVI_9497.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_9497.npy with shape (53, 1040)
# Processing MVI_9498.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_9498.npy with shape (53, 1040)
# Processing MVI_9499.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/cool/MVI_9499.npy with shape (56, 1040)
# ✅ Finished processing class 'cool' - Avg frames: 54.3
#
# ================== Processing Class: dry ==================
# Processing MVI_5167.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_5167.npy with shape (68, 1040)
# Processing MVI_5168.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_5168.npy with shape (80, 1040)
# Processing MVI_5169.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_5169.npy with shape (82, 1040)
# Processing MVI_5248.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_5248.npy with shape (58, 1040)
# Processing MVI_5249.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_5249.npy with shape (67, 1040)
# Processing MVI_5250.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_5250.npy with shape (67, 1040)
# Processing MVI_5326.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_5326.npy with shape (60, 1040)
# Processing MVI_5327.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_5327.npy with shape (58, 1040)
# Processing MVI_5328.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_5328.npy with shape (55, 1040)
# Processing MVI_9277.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_9277.npy with shape (57, 1040)
# Processing MVI_9278.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_9278.npy with shape (62, 1040)
# Processing MVI_9279.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_9279.npy with shape (56, 1040)
# Processing MVI_9359.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_9359.npy with shape (55, 1040)
# Processing MVI_9360.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_9360.npy with shape (53, 1040)
# Processing MVI_9361.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_9361.npy with shape (53, 1040)
# Processing MVI_9439.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_9439.npy with shape (63, 1040)
# Processing MVI_9440.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_9440.npy with shape (58, 1040)
# Processing MVI_9441.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_9441.npy with shape (57, 1040)
# Processing MVI_9521.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_9521.npy with shape (63, 1040)
# Processing MVI_9522.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_9522.npy with shape (64, 1040)
# Processing MVI_9523.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/dry/MVI_9523.npy with shape (66, 1040)
# ✅ Finished processing class 'dry' - Avg frames: 62.0
#
# ================== Processing Class: extra ==================
# Processing MVI_5209.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/extra/MVI_5209.npy with shape (68, 1040)
# ✅ Finished processing class 'extra' - Avg frames: 68.0
#
# ================== Processing Class: famous ==================
# Processing MVI_9715.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/famous/MVI_9715.npy with shape (51, 1040)
# Processing MVI_9716.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/famous/MVI_9716.npy with shape (58, 1040)
# Processing MVI_9717.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/famous/MVI_9717.npy with shape (48, 1040)
# Processing MVI_9718.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/famous/MVI_9718.npy with shape (50, 1040)
# Processing MVI_9839.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/famous/MVI_9839.npy with shape (62, 1040)
# Processing MVI_9841.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/famous/MVI_9841.npy with shape (49, 1040)
# Processing MVI_9842.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/famous/MVI_9842.npy with shape (50, 1040)
# Processing MVI_9843.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/famous/MVI_9843.npy with shape (52, 1040)
# ✅ Finished processing class 'famous' - Avg frames: 52.5
#
# ================== Processing Class: fast ==================
# Processing MVI_5133.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_5133.npy with shape (65, 1040)
# Processing MVI_5134.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_5134.npy with shape (70, 1040)
# Processing MVI_5135.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_5135.npy with shape (74, 1040)
# Processing MVI_5213.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_5213.npy with shape (56, 1040)
# Processing MVI_5214.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_5214.npy with shape (70, 1040)
# Processing MVI_5215.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_5215.npy with shape (65, 1040)
# Processing MVI_5292.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_5292.npy with shape (47, 1040)
# Processing MVI_5293.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_5293.npy with shape (55, 1040)
# Processing MVI_5294.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_5294.npy with shape (50, 1040)
# Processing MVI_9244.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_9244.npy with shape (45, 1040)
# Processing MVI_9245.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_9245.npy with shape (48, 1040)
# Processing MVI_9246.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_9246.npy with shape (46, 1040)
# Processing MVI_9325.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_9325.npy with shape (44, 1040)
# Processing MVI_9326.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_9326.npy with shape (48, 1040)
# Processing MVI_9327.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_9327.npy with shape (43, 1040)
# Processing MVI_9405.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_9405.npy with shape (51, 1040)
# Processing MVI_9406.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_9406.npy with shape (55, 1040)
# Processing MVI_9407.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_9407.npy with shape (53, 1040)
# Processing MVI_9484.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_9484.npy with shape (61, 1040)
# Processing MVI_9485.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_9485.npy with shape (67, 1040)
# Processing MVI_9486.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/fast/MVI_9486.npy with shape (62, 1040)
# ✅ Finished processing class 'fast' - Avg frames: 56.0
#
# ================== Processing Class: healthy ==================
# Processing MVI_5173.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_5173.npy with shape (67, 1040)
# Processing MVI_5174.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_5174.npy with shape (78, 1040)
# Processing MVI_5175.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_5175.npy with shape (95, 1040)
# Processing MVI_5254.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_5254.npy with shape (62, 1040)
# Processing MVI_5255.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_5255.npy with shape (70, 1040)
# Processing MVI_5256.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_5256.npy with shape (67, 1040)
# Processing MVI_5332.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_5332.npy with shape (52, 1040)
# Processing MVI_5333.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_5333.npy with shape (51, 1040)
# Processing MVI_5334.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_5334.npy with shape (54, 1040)
# Processing MVI_9286.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_9286.npy with shape (55, 1040)
# Processing MVI_9287.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_9287.npy with shape (61, 1040)
# Processing MVI_9288.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_9288.npy with shape (65, 1040)
# Processing MVI_9365.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_9365.npy with shape (55, 1040)
# Processing MVI_9366.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_9366.npy with shape (57, 1040)
# Processing MVI_9367.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_9367.npy with shape (50, 1040)
# Processing MVI_9445.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_9445.npy with shape (64, 1040)
# Processing MVI_9446.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_9446.npy with shape (60, 1040)
# Processing MVI_9447.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_9447.npy with shape (57, 1040)
# Processing MVI_9530.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_9530.npy with shape (61, 1040)
# Processing MVI_9531.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_9531.npy with shape (60, 1040)
# Processing MVI_9532.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/healthy/MVI_9532.npy with shape (62, 1040)
# ✅ Finished processing class 'healthy' - Avg frames: 62.0
#
# ================== Processing Class: hot ==================
# Processing MVI_5136.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_5136.npy with shape (71, 1040)
# Processing MVI_5137.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_5137.npy with shape (56, 1040)
# Processing MVI_5138.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_5138.npy with shape (49, 1040)
# Processing MVI_5216.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_5216.npy with shape (57, 1040)
# Processing MVI_5217.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_5217.npy with shape (66, 1040)
# Processing MVI_5218.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_5218.npy with shape (66, 1040)
# Processing MVI_5295.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_5295.npy with shape (56, 1040)
# Processing MVI_5296.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_5296.npy with shape (56, 1040)
# Processing MVI_5297.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_5297.npy with shape (55, 1040)
# Processing MVI_9247.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_9247.npy with shape (55, 1040)
# Processing MVI_9248.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_9248.npy with shape (48, 1040)
# Processing MVI_9249.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_9249.npy with shape (48, 1040)
# Processing MVI_9328.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_9328.npy with shape (52, 1040)
# Processing MVI_9329.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_9329.npy with shape (53, 1040)
# Processing MVI_9330.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_9330.npy with shape (50, 1040)
# Processing MVI_9408.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_9408.npy with shape (63, 1040)
# Processing MVI_9409.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_9409.npy with shape (66, 1040)
# Processing MVI_9410.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_9410.npy with shape (56, 1040)
# Processing MVI_9487.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_9487.npy with shape (63, 1040)
# Processing MVI_9488.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_9488.npy with shape (65, 1040)
# Processing MVI_9489.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/hot/MVI_9489.npy with shape (62, 1040)
# ✅ Finished processing class 'hot' - Avg frames: 57.8
#
# ================== Processing Class: light ==================
# Processing MVI_9711.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/light/MVI_9711.npy with shape (55, 1040)
# Processing MVI_9712.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/light/MVI_9712.npy with shape (56, 1040)
# Processing MVI_9713.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/light/MVI_9713.npy with shape (60, 1040)
# Processing MVI_9714.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/light/MVI_9714.npy with shape (60, 1040)
# Processing MVI_9835.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/light/MVI_9835.npy with shape (65, 1040)
# Processing MVI_9836.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/light/MVI_9836.npy with shape (63, 1040)
# Processing MVI_9837.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/light/MVI_9837.npy with shape (63, 1040)
# Processing MVI_9838.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/light/MVI_9838.npy with shape (60, 1040)
# ✅ Finished processing class 'light' - Avg frames: 60.2
#
# ================== Processing Class: long ==================
# Processing MVI_5106.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_5106.npy with shape (68, 1040)
# Processing MVI_5107.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_5107.npy with shape (71, 1040)
# Processing MVI_5108.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_5108.npy with shape (78, 1040)
# Processing MVI_5186.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_5186.npy with shape (64, 1040)
# Processing MVI_5187.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_5187.npy with shape (60, 1040)
# Processing MVI_5188.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_5188.npy with shape (51, 1040)
# Processing MVI_5266.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_5266.npy with shape (69, 1040)
# Processing MVI_5267.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_5267.npy with shape (62, 1040)
# Processing MVI_5268.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_5268.npy with shape (60, 1040)
# Processing MVI_9217.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_9217.npy with shape (52, 1040)
# Processing MVI_9218.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_9218.npy with shape (53, 1040)
# Processing MVI_9219.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_9219.npy with shape (53, 1040)
# Processing MVI_9298.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_9298.npy with shape (53, 1040)
# Processing MVI_9299.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_9299.npy with shape (50, 1040)
# Processing MVI_9300.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_9300.npy with shape (56, 1040)
# Processing MVI_9377.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_9377.npy with shape (53, 1040)
# Processing MVI_9378.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_9378.npy with shape (52, 1040)
# Processing MVI_9379.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_9379.npy with shape (52, 1040)
# Processing MVI_9458.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_9458.npy with shape (56, 1040)
# Processing MVI_9459.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_9459.npy with shape (51, 1040)
# Processing MVI_9460.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/long/MVI_9460.npy with shape (52, 1040)
# ✅ Finished processing class 'long' - Avg frames: 57.9
#
# ================== Processing Class: narrow ==================
# Processing MVI_5120.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_5120.npy with shape (77, 1040)
# Processing MVI_5121.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_5121.npy with shape (71, 1040)
# Processing MVI_5122.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_5122.npy with shape (59, 1040)
# Processing MVI_5200.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_5200.npy with shape (78, 1040)
# Processing MVI_5201.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_5201.npy with shape (82, 1040)
# Processing MVI_5202.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_5202.npy with shape (80, 1040)
# Processing MVI_5280.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_5280.npy with shape (70, 1040)
# Processing MVI_5281.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_5281.npy with shape (66, 1040)
# Processing MVI_5282.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_5282.npy with shape (58, 1040)
# Processing MVI_9230.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_9230.npy with shape (51, 1040)
# Processing MVI_9231.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_9231.npy with shape (53, 1040)
# Processing MVI_9232.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_9232.npy with shape (46, 1040)
# Processing MVI_9313.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_9313.npy with shape (45, 1040)
# Processing MVI_9314.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_9314.npy with shape (49, 1040)
# Processing MVI_9315.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_9315.npy with shape (48, 1040)
# Processing MVI_9391.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_9391.npy with shape (48, 1040)
# Processing MVI_9392.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_9392.npy with shape (54, 1040)
# Processing MVI_9393.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_9393.npy with shape (48, 1040)
# Processing MVI_9471.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_9471.npy with shape (59, 1040)
# Processing MVI_9472.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_9472.npy with shape (57, 1040)
# Processing MVI_9474.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/narrow/MVI_9474.npy with shape (54, 1040)
# ✅ Finished processing class 'narrow' - Avg frames: 59.7
#
# ================== Processing Class: new ==================
# Processing MVI_5148.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_5148.npy with shape (57, 1040)
# Processing MVI_5150.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_5150.npy with shape (64, 1040)
# Processing MVI_5151.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_5151.npy with shape (59, 1040)
# Processing MVI_5229.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_5229.npy with shape (54, 1040)
# Processing MVI_5230.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_5230.npy with shape (57, 1040)
# Processing MVI_5231.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_5231.npy with shape (62, 1040)
# Processing MVI_5307.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_5307.npy with shape (39, 1040)
# Processing MVI_5308.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_5308.npy with shape (42, 1040)
# Processing MVI_5309.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_5309.npy with shape (46, 1040)
# Processing MVI_9259.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_9259.npy with shape (46, 1040)
# Processing MVI_9260.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_9260.npy with shape (49, 1040)
# Processing MVI_9261.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_9261.npy with shape (49, 1040)
# Processing MVI_9340.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_9340.npy with shape (49, 1040)
# Processing MVI_9341.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_9341.npy with shape (49, 1040)
# Processing MVI_9342.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_9342.npy with shape (47, 1040)
# Processing MVI_9421.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_9421.npy with shape (63, 1040)
# Processing MVI_9422.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_9422.npy with shape (47, 1040)
# Processing MVI_9423.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_9423.npy with shape (49, 1040)
# Processing MVI_9500.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_9500.npy with shape (56, 1040)
# Processing MVI_9501.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_9501.npy with shape (49, 1040)
# Processing MVI_9502.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/new/MVI_9502.npy with shape (52, 1040)
# ✅ Finished processing class 'new' - Avg frames: 51.7
#
# ================== Processing Class: short ==================
# Processing MVI_5110.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_5110.npy with shape (62, 1040)
# Processing MVI_5111.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_5111.npy with shape (68, 1040)
# Processing MVI_5112.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_5112.npy with shape (61, 1040)
# Processing MVI_5189.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_5189.npy with shape (57, 1040)
# Processing MVI_5190.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_5190.npy with shape (56, 1040)
# Processing MVI_5191.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_5191.npy with shape (64, 1040)
# Processing MVI_5269.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_5269.npy with shape (51, 1040)
# Processing MVI_5270.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_5270.npy with shape (51, 1040)
# Processing MVI_5271.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_5271.npy with shape (52, 1040)
# Processing MVI_9220.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_9220.npy with shape (49, 1040)
# Processing MVI_9221.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_9221.npy with shape (44, 1040)
# Processing MVI_9222.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_9222.npy with shape (49, 1040)
# Processing MVI_9301.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_9301.npy with shape (49, 1040)
# Processing MVI_9302.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_9302.npy with shape (44, 1040)
# Processing MVI_9303.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_9303.npy with shape (49, 1040)
# Processing MVI_9380.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_9380.npy with shape (53, 1040)
# Processing MVI_9381.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_9381.npy with shape (47, 1040)
# Processing MVI_9382.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_9382.npy with shape (45, 1040)
# Processing MVI_9461.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_9461.npy with shape (57, 1040)
# Processing MVI_9462.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_9462.npy with shape (54, 1040)
# Processing MVI_9463.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/short/MVI_9463.npy with shape (56, 1040)
# ✅ Finished processing class 'short' - Avg frames: 53.2
#
# ================== Processing Class: sick ==================
# Processing MVI_5170.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_5170.npy with shape (70, 1040)
# Processing MVI_5171.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_5171.npy with shape (85, 1040)
# Processing MVI_5172.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_5172.npy with shape (78, 1040)
# Processing MVI_5251.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_5251.npy with shape (66, 1040)
# Processing MVI_5252.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_5252.npy with shape (62, 1040)
# Processing MVI_5253.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_5253.npy with shape (60, 1040)
# Processing MVI_5329.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_5329.npy with shape (47, 1040)
# Processing MVI_5330.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_5330.npy with shape (51, 1040)
# Processing MVI_5331.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_5331.npy with shape (55, 1040)
# Processing MVI_9280.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_9280.npy with shape (56, 1040)
# Processing MVI_9281.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_9281.npy with shape (54, 1040)
# Processing MVI_9282.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_9282.npy with shape (65, 1040)
# Processing MVI_9362.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_9362.npy with shape (47, 1040)
# Processing MVI_9363.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_9363.npy with shape (44, 1040)
# Processing MVI_9364.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_9364.npy with shape (45, 1040)
# Processing MVI_9442.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_9442.npy with shape (58, 1040)
# Processing MVI_9443.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_9443.npy with shape (60, 1040)
# Processing MVI_9444.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_9444.npy with shape (56, 1040)
# Processing MVI_9527.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_9527.npy with shape (64, 1040)
# Processing MVI_9528.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_9528.npy with shape (69, 1040)
# Processing MVI_9529.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/sick/MVI_9529.npy with shape (64, 1040)
# ✅ Finished processing class 'sick' - Avg frames: 59.8
#
# ================== Processing Class: slow ==================
# Processing MVI_5130.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_5130.npy with shape (67, 1040)
# Processing MVI_5131.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_5131.npy with shape (89, 1040)
# Processing MVI_5132.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_5132.npy with shape (77, 1040)
# Processing MVI_5210.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_5210.npy with shape (69, 1040)
# Processing MVI_5211.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_5211.npy with shape (75, 1040)
# Processing MVI_5212.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_5212.npy with shape (65, 1040)
# Processing MVI_5289.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_5289.npy with shape (63, 1040)
# Processing MVI_5290.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_5290.npy with shape (52, 1040)
# Processing MVI_5291.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_5291.npy with shape (58, 1040)
# Processing MVI_9240.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_9240.npy with shape (57, 1040)
# Processing MVI_9242.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_9242.npy with shape (39, 1040)
# Processing MVI_9243.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_9243.npy with shape (46, 1040)
# Processing MVI_9322.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_9322.npy with shape (50, 1040)
# Processing MVI_9323.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_9323.npy with shape (57, 1040)
# Processing MVI_9324.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_9324.npy with shape (54, 1040)
# Processing MVI_9402.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_9402.npy with shape (60, 1040)
# Processing MVI_9403.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_9403.npy with shape (64, 1040)
# Processing MVI_9404.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_9404.npy with shape (62, 1040)
# Processing MVI_9481.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_9481.npy with shape (62, 1040)
# Processing MVI_9482.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_9482.npy with shape (59, 1040)
# Processing MVI_9483.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/slow/MVI_9483.npy with shape (65, 1040)
# ✅ Finished processing class 'slow' - Avg frames: 61.4
#
# ================== Processing Class: small little ==================
# Processing MVI_5126.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_5126.npy with shape (83, 1040)
# Processing MVI_5127.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_5127.npy with shape (80, 1040)
# Processing MVI_5128.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_5128.npy with shape (62, 1040)
# Processing MVI_5206.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_5206.npy with shape (53, 1040)
# Processing MVI_5207.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_5207.npy with shape (57, 1040)
# Processing MVI_5208.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_5208.npy with shape (58, 1040)
# Processing MVI_5286.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_5286.npy with shape (52, 1040)
# Processing MVI_5287.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_5287.npy with shape (54, 1040)
# Processing MVI_5288.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_5288.npy with shape (38, 1040)
# Processing MVI_9236.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_9236.npy with shape (44, 1040)
# Processing MVI_9237.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_9237.npy with shape (52, 1040)
# Processing MVI_9238.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_9238.npy with shape (51, 1040)
# Processing MVI_9319.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_9319.npy with shape (51, 1040)
# Processing MVI_9320.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_9320.npy with shape (52, 1040)
# Processing MVI_9321.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_9321.npy with shape (54, 1040)
# Processing MVI_9397.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_9397.npy with shape (51, 1040)
# Processing MVI_9398.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_9398.npy with shape (50, 1040)
# Processing MVI_9400.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_9400.npy with shape (53, 1040)
# Processing MVI_9478.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_9478.npy with shape (54, 1040)
# Processing MVI_9479.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_9479.npy with shape (52, 1040)
# Processing MVI_9480.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/small little/MVI_9480.npy with shape (55, 1040)
# ✅ Finished processing class 'small little' - Avg frames: 55.0
#
# ================== Processing Class: tall ==================
# Processing MVI_5114.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_5114.npy with shape (64, 1040)
# Processing MVI_5115.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_5115.npy with shape (72, 1040)
# Processing MVI_5116.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_5116.npy with shape (64, 1040)
# Processing MVI_5194.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_5194.npy with shape (52, 1040)
# Processing MVI_5195.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_5195.npy with shape (60, 1040)
# Processing MVI_5196.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_5196.npy with shape (58, 1040)
# Processing MVI_5273.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_5273.npy with shape (59, 1040)
# Processing MVI_5274.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_5274.npy with shape (54, 1040)
# Processing MVI_5276.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_5276.npy with shape (55, 1040)
# Processing MVI_9223.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_9223.npy with shape (48, 1040)
# Processing MVI_9224.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_9224.npy with shape (59, 1040)
# Processing MVI_9225.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_9225.npy with shape (48, 1040)
# Processing MVI_9307.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_9307.npy with shape (58, 1040)
# Processing MVI_9308.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_9308.npy with shape (50, 1040)
# Processing MVI_9309.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_9309.npy with shape (58, 1040)
# Processing MVI_9384.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_9384.npy with shape (57, 1040)
# Processing MVI_9386.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_9386.npy with shape (60, 1040)
# Processing MVI_9387.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_9387.npy with shape (45, 1040)
# Processing MVI_9464.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_9464.npy with shape (58, 1040)
# Processing MVI_9465.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_9465.npy with shape (50, 1040)
# Processing MVI_9466.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/tall/MVI_9466.npy with shape (50, 1040)
# ✅ Finished processing class 'tall' - Avg frames: 56.1
#
# ================== Processing Class: warm ==================
# Processing MVI_5141.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_5141.npy with shape (67, 1040)
# Processing MVI_5143.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_5143.npy with shape (69, 1040)
# Processing MVI_5144.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_5144.npy with shape (70, 1040)
# Processing MVI_5222.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_5222.npy with shape (60, 1040)
# Processing MVI_5223.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_5223.npy with shape (62, 1040)
# Processing MVI_5224.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_5224.npy with shape (67, 1040)
# Processing MVI_5301.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_5301.npy with shape (53, 1040)
# Processing MVI_5302.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_5302.npy with shape (55, 1040)
# Processing MVI_5303.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_5303.npy with shape (46, 1040)
# Processing MVI_9253.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_9253.npy with shape (48, 1040)
# Processing MVI_9254.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_9254.npy with shape (59, 1040)
# Processing MVI_9255.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_9255.npy with shape (51, 1040)
# Processing MVI_9334.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_9334.npy with shape (55, 1040)
# Processing MVI_9335.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_9335.npy with shape (57, 1040)
# Processing MVI_9336.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_9336.npy with shape (53, 1040)
# Processing MVI_9415.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_9415.npy with shape (77, 1040)
# Processing MVI_9416.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_9416.npy with shape (74, 1040)
# Processing MVI_9417.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_9417.npy with shape (66, 1040)
# Processing MVI_9493.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_9493.npy with shape (71, 1040)
# Processing MVI_9494.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_9494.npy with shape (66, 1040)
# Processing MVI_9495.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/warm/MVI_9495.npy with shape (70, 1040)
# ✅ Finished processing class 'warm' - Avg frames: 61.7
#
# ================== Processing Class: wide ==================
# Processing MVI_5117.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_5117.npy with shape (61, 1040)
# Processing MVI_5118.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_5118.npy with shape (48, 1040)
# Processing MVI_5119.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_5119.npy with shape (68, 1040)
# Processing MVI_5197.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_5197.npy with shape (70, 1040)
# Processing MVI_5198.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_5198.npy with shape (70, 1040)
# Processing MVI_5199.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_5199.npy with shape (71, 1040)
# Processing MVI_5277.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_5277.npy with shape (57, 1040)
# Processing MVI_5278.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_5278.npy with shape (65, 1040)
# Processing MVI_5279.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_5279.npy with shape (60, 1040)
# Processing MVI_9227.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_9227.npy with shape (39, 1040)
# Processing MVI_9228.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_9228.npy with shape (49, 1040)
# Processing MVI_9229.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_9229.npy with shape (46, 1040)
# Processing MVI_9310.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_9310.npy with shape (51, 1040)
# Processing MVI_9311.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_9311.npy with shape (55, 1040)
# Processing MVI_9312.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_9312.npy with shape (53, 1040)
# Processing MVI_9388.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_9388.npy with shape (51, 1040)
# Processing MVI_9389.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_9389.npy with shape (60, 1040)
# Processing MVI_9390.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_9390.npy with shape (59, 1040)
# Processing MVI_9467.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_9467.npy with shape (61, 1040)
# Processing MVI_9468.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_9468.npy with shape (53, 1040)
# Processing MVI_9469.MOV...
# Saved landmarks to Data/INCLUDE/Adjectives/Landmarks/wide/MVI_9469.npy with shape (55, 1040)
# ✅ Finished processing class 'wide' - Avg frames: 57.2
#
# ========================================================
#                     📊 FINAL SUMMARY
# ========================================================
#   ▶️  Class 'big large': 55.62 average frames
#   ▶️  Class 'cold': 55.70 average frames
#   ▶️  Class 'cool': 54.29 average frames
#   ▶️  Class 'dry': 62.00 average frames
#   ▶️  Class 'extra': 68.00 average frames
#   ▶️  Class 'famous': 52.50 average frames
#   ▶️  Class 'fast': 55.95 average frames
#   ▶️  Class 'healthy': 62.05 average frames
#   ▶️  Class 'hot': 57.76 average frames
#   ▶️  Class 'light': 60.25 average frames
#   ▶️  Class 'long': 57.90 average frames
#   ▶️  Class 'narrow': 59.67 average frames
#   ▶️  Class 'new': 51.67 average frames
#   ▶️  Class 'short': 53.24 average frames
#   ▶️  Class 'sick': 59.81 average frames
#   ▶️  Class 'slow': 61.43 average frames
#   ▶️  Class 'small little': 55.05 average frames
#   ▶️  Class 'tall': 56.14 average frames
#   ▶️  Class 'warm': 61.71 average frames
#   ▶️  Class 'wide': 57.24 average frames
